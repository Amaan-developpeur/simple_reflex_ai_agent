# %%
from model_loader import loading_model
from sensor import sense
from decision import decision
from agent_loop import agent_loop
from files import image_paths
from logger import save_logs
from environment import add_true_label_column
from reward import get_reward, apply_rewards

# %%
model = loading_model('full_model.keras')

# %%
image_paths = image_paths()

# %%
predicted_class, confidence = sense(image_path=image_paths[0], model_Name=model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
logs = agent_loop(image_paths, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# ...

# %%
df = save_logs(logs)

# %%
df
# Out:
#                             image_path predicted_class  confidence  \
# 0    split\val\cataract\1062_right.jpg        Cataract    0.943620
# 1     split\val\cataract\1285_left.jpg        Cataract    0.910126
# 2     split\val\cataract\1415_left.jpg          Normal    0.854095
# 3    split\val\cataract\1454_right.jpg        Cataract    0.809608
# 4    split\val\cataract\1483_right.jpg          Normal    0.907182
# ..                                 ...             ...         ...
# 832     split\val\normal\3434_left.jpg          Normal    0.853351
# 833    split\val\normal\3442_right.jpg          Normal    0.999809
# 834     split\val\normal\3445_left.jpg          Normal    0.999990
# 835    split\val\normal\3448_right.jpg          Normal    0.840643
# 836       split\val\normal\8_right.jpg          Normal    0.983014
#
#                                   action
# 0              Schedule surgical consult
# 1              Schedule surgical consult
# ...

# %%
df = add_true_label_column(df)

# %%
df
# Out:
#                             image_path predicted_class  confidence  \
# 0    split\val\cataract\1062_right.jpg        Cataract    0.943620
# 1     split\val\cataract\1285_left.jpg        Cataract    0.910126
# 2     split\val\cataract\1415_left.jpg          Normal    0.854095
# 3    split\val\cataract\1454_right.jpg        Cataract    0.809608
# 4    split\val\cataract\1483_right.jpg          Normal    0.907182
# ..                                 ...             ...         ...
# 832     split\val\normal\3434_left.jpg          Normal    0.853351
# 833    split\val\normal\3442_right.jpg          Normal    0.999809
# 834     split\val\normal\3445_left.jpg          Normal    0.999990
# 835    split\val\normal\3448_right.jpg          Normal    0.840643
# 836       split\val\normal\8_right.jpg          Normal    0.983014
#
#                                   action true_label
# 0              Schedule surgical consult   Cataract
# 1              Schedule surgical consult   Cataract
# ...

# %%
df = apply_rewards(df)

# %%
df
# Out:
#                             image_path predicted_class  confidence  \
# 0    split\val\cataract\1062_right.jpg        Cataract    0.943620
# 1     split\val\cataract\1285_left.jpg        Cataract    0.910126
# 2     split\val\cataract\1415_left.jpg          Normal    0.854095
# 3    split\val\cataract\1454_right.jpg        Cataract    0.809608
# 4    split\val\cataract\1483_right.jpg          Normal    0.907182
# ..                                 ...             ...         ...
# 832     split\val\normal\3434_left.jpg          Normal    0.853351
# 833    split\val\normal\3442_right.jpg          Normal    0.999809
# 834     split\val\normal\3445_left.jpg          Normal    0.999990
# 835    split\val\normal\3448_right.jpg          Normal    0.840643
# 836       split\val\normal\8_right.jpg          Normal    0.983014
#
#                                   action true_label  reward
# 0              Schedule surgical consult   Cataract     0.0
# ...
