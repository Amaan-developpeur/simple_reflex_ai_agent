# %%
from pathlib import Path
import sys

# %%
# This works inside Jupyter notebooks
ROOT = Path().resolve().parent  # Get parent of notebooks/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

print("✅ sys.path updated with:", ROOT)
# Out:
# ✅ sys.path updated with: C:\Users\DELL\Data Science\Deep Learning\Project\simple_reflex_ai_agent

# %%
BASE_DIR = Path('simple_reflex_ai_agent')

# %%
from agent.model_loader import loading_model
from agent.sensor import sense
from agent.decision import decision
from agent.agent_loop import agent_loop
from agent.files import image_paths
from agent.logger import save_logs
from agent.environment import add_true_label_column
from agent.reward import get_reward, apply_rewards

# %%
# from pathlib import Path

# project_root = Path().resolve().parent
# print("Looking in:", project_root)

# # Show all folders/files in project root
# print("\nProject root contents:")
# for item in project_root.iterdir():
#     print("📁" if item.is_dir() else "📄", item.name)

# %%
# agent_dir = project_root / 'agent'
# print("Contents of agent/:")
# for item in agent_dir.iterdir():
#     print("📄", item.name)

# %%
# Go up one level from notebooks/ to the project root
BASE_DIR = Path().resolve().parent
model_path = BASE_DIR / 'models' / 'full_model.keras'

model = loading_model(model_path)

# %%
image_paths = image_paths()
# Out:
# 📂 Looking in: C:\Users\DELL\Data Science\Deep Learning\Project\split\val

# %%
predicted_class, confidence = sense(image_path=image_paths[0], model_Name=model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
logs = agent_loop(image_paths, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# ...

# %%
df = save_logs(logs)

# %%
df
# Out:
#                                             image_path predicted_class  \
# 0    C:\Users\DELL\Data Science\Deep Learning\Proje...        Cataract
# 1    C:\Users\DELL\Data Science\Deep Learning\Proje...        Cataract
# 2    C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 3    C:\Users\DELL\Data Science\Deep Learning\Proje...        Cataract
# 4    C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# ..                                                 ...             ...
# 832  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 833  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 834  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 835  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 836  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
#
#      confidence                               action
# 0      0.943620            Schedule surgical consult
# ...

# %%
df = add_true_label_column(df)

# %%
df
# Out:
#                                             image_path predicted_class  \
# 0    C:\Users\DELL\Data Science\Deep Learning\Proje...        Cataract
# 1    C:\Users\DELL\Data Science\Deep Learning\Proje...        Cataract
# 2    C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 3    C:\Users\DELL\Data Science\Deep Learning\Proje...        Cataract
# 4    C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# ..                                                 ...             ...
# 832  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 833  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 834  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 835  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 836  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
#
#      confidence                               action true_label
# ...

# %%
df = apply_rewards(df)

# %%
df
# Out:
#                                             image_path predicted_class  \
# 0    C:\Users\DELL\Data Science\Deep Learning\Proje...        Cataract
# 1    C:\Users\DELL\Data Science\Deep Learning\Proje...        Cataract
# 2    C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 3    C:\Users\DELL\Data Science\Deep Learning\Proje...        Cataract
# 4    C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# ..                                                 ...             ...
# 832  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 833  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 834  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 835  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
# 836  C:\Users\DELL\Data Science\Deep Learning\Proje...          Normal
#
#      confidence                               action true_label  reward
# ...
